# %%
import os

raw_path = "../Data/raw"

files = os.listdir(raw_path)

print("FILES:")
for f in files:
    print(f)
# Out:
# -----------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       2
#       3 raw_path = "../Data/raw"
#       4
# ----> 5 files = os.listdir(raw_path)
#       6
#       7 print("FILES:")
#       8 for f in files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../Data/raw'

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\Dell\OneDrive\Desktop\Fintech_Data_Analytics

# %%
import os

print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', 'dashboard', 'Data', 'Notebooks', 'requirements.txt', 'Scripts', 'sql', 'Untitled.ipynb', 'venv']

# %%
import os

files = os.listdir("Data/raw")

for f in files:
    print(f)
# Out:
# 01_fund_master.csv
# 02_nav_history.csv
# 03_aum_by_fund_house.csv
# 04_monthly_sip_inflows.csv
# 05_category_inflows.csv
# 06_industry_folio_count.csv
# 07_scheme_performance.csv
# 08_investor_transactions.csv
# 09_portfolio_holdings.csv
# 10_benchmark_indices.csv
# live_nav_hdfc.csv
# nav_118632.csv
# nav_119092.csv
# nav_119551.csv
# nav_120503.csv
# nav_120841.csv
